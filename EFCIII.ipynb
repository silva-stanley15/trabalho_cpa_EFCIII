# %% [markdown]
# # UNIVERSIDADE FEDERAL DE LAVRAS
# ## Stanley Silva <br> Vitoria Alvim

# %% [markdown]
# ## 1. (42%) Defina com detalhes 𝒩𝒫 𝐶𝑜𝑚𝑝𝑙𝑒𝑡𝑢𝑑𝑒. Forneça todas as definições, conceitos e características necessários para explicar essa teoria. Dê exemplos.

# %% [markdown]
# a. Explique problemas, problemas de decisão e de otimização e instância de um problema<br>
# **RESPOSTA:** Os problemas são perguntas científicas relevantes que necessitam ser respondidas. Um problema é descrito como uma descrição geral de todos os seus parâmetros e uma expressão  de quais propriedades a resposta (ou solução) exige. “Quanto de memória seria necessário para armazenar o genoma humano?”, ou “qual a distância da terra para o sol?”, são exemplos de questões/problemas levantadas.</p>
# <p> Os problemas de decisão são descritos na computação como uma questão sobre um sistema formal com uma resposta do tipo sim ou não. Um problema de decisão pode ser definido como:</p>
# <ul>
#   <li> Seja um verificador para uma linguagem L como um algoritmo de dois argumentos:
#   <ul>
#     <li> uma String de entrada x; </li>
#     <li> Uma String binária t chamada certificado; </li>
#   </ul>
#   <li> Então $K(x,t) = e_s ∊ E$ em que *E* é o conjunto de estados de uma MTD (Máquina de Turing Determinística), $e_s$ é o estado de parada de aceitação, $K$ aceita $(x,t)$;</li>
# </ul>
#
# <p> Assim, se um problema pode ser expresso por uma máquina de turing determinística, ele é um problema de decisão. <br>
# <p> Os problemas do tipo de otimização são problemas que visam encontrar a melhor solução possível para entre diversas soluções viáveis. Vamos citar, por exemplo, o problema de encontrar a rota mais curta entre dois pontos. Aplicando o algoritmo de Dijkstra podemos encontrar a melhor solução entre esses dois pontos. <br>
# <p> A instância de um problema pode ser considerada como uma de todas as suas possíveis entradas. Usando o seguinte subconjunto {-8, -5, -4, -1, 3, 9}, a soma de alguns desses elementos seria 0? Considerando a entrada/instância {-8, -1, 9}, e somando esses elementos o resultado final é 0.

# %% [markdown]
# b. Explique algoritmos, tempo de execução de algoritmo, tamanho da entrada de algoritmos<br>
# **RESPOSTA:** Algoritmos pode ser compreendido como uma sequência de passos para se resolver um problema, executar algo, chegar no seu objetivo.
# <p> O tempo de execução de um algoritmo pode ser determinado como a quantidade de tempo que ele gastaria para executar uma entrada, ou seja, após receber uma entrada quando tempo o algoritmo leva para processá-la e retornar uma saída.
# <p> O tamanho da entrada de algoritmos de modo geral seria o número de elementos que serão processados.

# %% [markdown]
# c. A 𝒩𝒫 𝐶𝑜𝑚𝑝𝑙𝑒𝑡𝑢𝑑𝑒 só trata de problemas de decisão? Por quê? Faça uma resposta abrangente, inclua outros problemas. <br>
# **RESPOSTA:** A classe NP completude trata de todos os problemas computacionais que podem ser resolvidos em tempo polinomial de no máximo $c^n$. Os problemas de decisão, estão contidos no subconjunto de problemas *NP Completos*. Porém, ainda na classe *NP Completude* estão contidos os problemas de otimização, localização e outros problemas, como *Graph Isomorphism* (Isomorfismo de Grafos - bijeção entre os conjuntos de vértices de *G* e *H* de tal forma que quaisquer dois vértices *u* e *v* de *G* são adjacentes em *G* se e somente se $f(u)$ e $f(v)$ são adjacentes em *H*), e *Hamiltonian Cycle* (Ciclos Hamiltonianos - um caminho que permite passar por todos os caminhos possíveis de um grafo *G*, sem contudo não repetir nenhum vértice). Portanto, como visto no diagrama abaixo, os problemas de decisão fazem parte da classe *NP Completo* que é um subconjunto de *NP Completude*.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# d. Explique em que situações pode-se afirmar que um problema pertence a classe 𝒩𝒫 <br>
# **RESPOSTA:**
# Problemas para os quais a resposta seja “sim” ou “não”, um exemplo seria o problema do caixeiro viajante.

# %% [markdown]
# e. Explique as classes 𝒫 e 𝒩𝒫, incluindo termos de linguagem de máquinas de Turing.<br>
# **RESPOSTA:** Na classe NP estão os problemas de decisões, problemas que podem ser verificados em tempo polinomial e a classe de linguagem é reconhecida por máquinas de turing não determinísticas. Se para um linguagem L existe uma máquina de turing não determinística de tempo polinomial, ela pertence a classe NP.
# <p> Na classe P estão os problemas que são tratáveis em tempo polinomial e a classe de linguagem é reconhecida por Máquinas de Turing determinísticas. Se para um linguagem L existe uma máquina de turing determinística de tempo polinomial, ela pertence a classe P.
# <p> Sabe-se que uma Máquina de Turing possui alguns elementos, como alfabeto, estados, função de transições, estados de rejeição, aceitação e inicial, entre outros. Uma máquina de Turing não determinística chega em estado de aceitação da palavra se ela seguir um processamento que ao final seja válido, visto que para essa máquina possui caminhos alternativos no seu processamento. Já uma Máquina de Turing determinística apenas um caminho é válido para se chegar no seu estado de aceitação.

# %% [markdown]
# f. Qual a importância das reduções polinomiais no contexto de 𝒩𝒫 C𝑜𝑚𝑝𝑙𝑒𝑡𝑢𝑑𝑒. <br>
# **RESPOSTA:** Dada a definição de NP Completude, que são os problemas que podem ser reduzidos em uma solução em tempo polinomial, a redução é importante pois:
# <ul>
# <li> Embora um problema de ordem O(n20) ou O(n100) possa ser chamado de intratável, existem muitos poucos problemas práticos com tais ordens de tempo polinomial</li>
# <li> Para razões de modelos matemáticos, um problema que pode ser resolvido em tempo polinomial em um modelo também pode ser resolvido por outro modelo, também de tempo polinomial;
# </li>
# <li> A classe de problemas de tempo polinomial é solvível porque a adição e a multiplicação de polinômios são operações próximas, o que é conveniente para algoritmos na máquina de Turing.</li>
# </ul>

# %% [markdown]
# g. Defina as classes 𝒩𝒫 Completo e 𝒩𝒫 Difícil e as relações entre elas e com as classes 𝒫 e 𝒩𝒫. <br>
# **RESPOSTA:** Na classe NP-difícil estão os “problemas tão difíceis quanto os problemas mais difíceis  da classe NP” e não pertencem, necessariamente, à classe NP.
# <p> Para um problema ser um NP difícil, ele tem que pertencer a classe NP Completo e for uma problema Turing-redutível em tempo polinomial .
# <p> Na classe NP Completo estão os problemas pertencentes à classe NP e que se ele pode ser resolvido em tempo polinomial, então os problemas da classe NP Completo terão sua solução em tempo polinomial.
# <p> Os problemas da classe NP-Completo pertencem à classe NP e NP-Difícil.

# %% [markdown]
# ## 2. (29%) Considere que SAT pertence a classe 𝒩𝒫-Completo. Prove que SAT ∝ 3SAT.

# %% [markdown]
# Transformando uma instância $F$ de SAT em uma instância $F_3$
# de 3SAT:
# <p> Suponha que $F = C1.C2. . . . .Cm$. Considere uma cláusula
# $C = (x_1 + x_2 + . . . + x_k )$ de $F$ com $k$ literais.
# <ul>
# <li> se $k = 3$, coloque $C$ em $F_3$.</li>
# <li> se $k = 2$, coloque a cláusula
# $$C′ = (x_1 + x_2 + z).(x_1 + x_2 + \bar{z})$$
# em $F_3$, criando assim mais uma variável. E claro que uma atribuição de valores às variáveis irá satisfazer $C$ se
# e somente se ela satisfizer também a $C′$.</li>
# <li>
# se $k = 1$, coloque a cláusula
# $$C′ = (x_1 + y + z).(x_1 + \bar{y} + z).(x_1 + y + \bar{z}).(x_1 + \bar{y} + \bar{z})$$
# em $F3$, criando assim mais duas variáveis. Pode-se mostrar
# que uma atribuição de valores as variáveis irá satisfazer C se e
# somente se ela satisfizer também a C′.
# </li>
# <li>
# Se $k ≥ 4$, coloque a cláusula:
# $$ C′ = (x_1 + x_2 + y_1).(x_3 + \bar{y_1} + y2).(x_4 + \bar{y_2} + y_3). . . .
# . . . .(x_{k−2} + \bar{y}_{k−4} + y_{k−3}).(x_{k−1} + x_k + y_{k−3}) $$
# em $F3$, criando assim $k − 3$ novas variáveis.
#
# </li>
# </ul>
#
# <br>
#
# **Lema:** $C$ é SAT se e somente se $C′$ é SAT. <br>
#
# **Prova do Lema**
#
# $(\Rightarrow): $ Existe um $i$ para o qual $x_i = 1$. Se fizermos $y_j = 1$ para
# todo $j = 1, . . . , i − 2$ e $y_j = 0$ para todo $j = i − 1, . . . , k − 3$,
# teremos uma atribuição para a qual C′ é SAT.
#
#
# $(\Leftarrow ):$ se $C′$ é SAT, existe uma atribuição onde pelo menos um
# $x_i$ vale 1. Caso contrário, $C′$
# seria equivalente a
# $$ C′ = (y_1).(\bar{y_1} + y_2).(\bar{y_2} + y_3). . . . .(\bar{y}_{k−4} + y_{k−3}).(\bar{y}_{k−3} )$$
# que obviamente não é SAT.
#
# <ul>
# <li>Portanto, se $F$ tem $m$ cláusulas e $n$ variáveis, $F_3$ terá $O(nm)$
# cláusulas e variáveis. </li>
# <li> Por construção, $F$ é SAT se e somente se $F_3$ é SAT. </li>
# </ul>

# %% [markdown]
# ## 3.(29%) Explique os problemas 3SAT e CLIQUE. Considere que 3SAT pertence a classe 𝒩𝒫-Completo. Prove que o CLIQUE pertence a classe 𝒩𝒫-Completo.

# %% [markdown]
# Demonstração: Seja ${\Phi = (X,C)}$ uma instância de SAT e vamos construir uma instância ${(G, |C|)}$ de CLIQUE.
#
# Se ${\Phi}$ tem cláusulas ${C_1,C_2,\dots,C_k}$ então ${G}$ tem ${3k}$ vértices denotados ${v_{i,j}}$, para ${1\leq i \leq k}$ e ${1\leq j \leq 3}$. O vértice ${v_{i,j}}$ corresponde ao literal ${j}$ da cláusula ${i}$, denotado ${\ell_{i,j}}$. As arestas são dadas pelos pares de vértices $\displaystyle \{ v_{i,j} ,v_{k,l}\}$ com ${i\neq k}$ (correspondem a cláusulas diferentes) e cujos literais podem ser simultaneamente verdadeiros (não contraditórios). Notemos que ${C_i= \{\ell_{i,1}, \ell_{i,2},\ell_{i,3}\}}$ corresponde a um conjunto independente ${\{v_{i_1}, v_{i_2},v_{i_3}\}}$ em ${G}$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Seja ${t}$ uma atribuição que satisfaz todas as cláusulas de ${\Phi}$ e sejam ${\ell_{1,j_1},\dots,\ell_{k,j_k}}$ um literal com valor ${{verdadeiro}}$ de cada cláusula. Então ${v_{1,j_1},v_{2,j_j},\dots,v_{k,j_k}}$ é um clique com ${k}$-vértices em ${G}$.
#
# Agora, suponha que ${G}$ tem um clique com pelo menos ${k}$ vértices. Seja ${U}$ um subconjunto de vértices de cardinalidade ${k}$ que define um clique em ${G}$. Como vértices da mesma cláusula não são adjacentes, devemos ter um vértice correspondente a cada cláusula de ${\Phi}$. Definimos a seguinte atribuição na variáveis de ${\Phi}$: se ${x}$ é uma variável que corresponde a um vértice de ${U}$ então ${t(x)}$ é verdadeiro, caso contrário, ${t(x)}$ é falso. Assim ${t}$ satisfaz todas as cláusulas.
#
# Resta mostrar que essa construção pode ser feita em tempo polinomial no tamanho da descrição de ${\Phi}$. Basta notar que ${G}$ tem ${3k}$ vértices portanto construímos uma matriz de tamanho ${9k^2}$ que é polinomial no tamanho da representação de ${\Phi}$.

# %% [markdown]
# ## Problema da mochila

# %%
import random
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
def gerarVetorV(n):
  A = []
  for i in range(n):
    A.append(random.randrange(10, 300, 10))
  return A

def gerarVetorP(n):
  A = []
  for i in range(n):
    A.append(random.randrange(10, 100, 10))
  return A

# %%
def mochila(capacidade, pesos, valores, n):
  ini= time.time()
  vetor = [[0 for x in range(capacidade + 1)] for x in range(n + 1)]

  for i in range(n + 1):
      for w in range(capacidade + 1):
          if i == 0 or w == 0:
              vetor[i][w] = 0
          elif pesos[i-1] <= w:
              vetor[i][w] = max(valores[i-1] + vetor[i-1][w-pesos[i-1]],  vetor[i-1][w])
          else:
              vetor[i][w] = vetor[i-1][w]
  fim = time.time()
  tempo_exec=fim-ini
  return tempo_exec

# %%
aux = []
numEntradas = []

for i in range (5, 30):
  numEntradas.append(i)
  valores = gerarVetorV(i)
  pesos = gerarVetorP(i)
  capacidade = 50
  aux.append(mochila(capacidade, pesos, valores, i))


plt.plot(numEntradas,aux, 'r', label='subsetsum')
plt.xlabel("qtde entradas")
plt.ylabel("tempo")
plt.legend()
plt.show()
